# %% [markdown]
# # X4 - 7 Shell Module + 3DPC
# ## FB = 3.75 cm, and RB = 2.5665 cm
# ### Jul, 2018
# ### Milo BC - Berkeley
# ### White Sands Missile Range

# %%
from foxsisim.util import load_rays
from foxsisim.detector import Detector
import matplotlib.pyplot as plt 
import matplotlib.patches as patches
import numpy as np

paper = 227.8
fbr = 3.75
rbr = 2.5665 
offaxisAngles = np.arange(0.0,2.,0.2) # Off-Axis Angles

NF_R262_All_Drays, NF_R262_All_Hrays, NF_R262_All_Prays, NF_R262_All_Srays = [], [], [], []
NF_R262_All_Hx, NF_R262_All_Hy, NF_R262_All_Px, NF_R262_All_Py, NF_R262_All_Dx, NF_R262_All_Dy = [], [], [], [], [], []
NF_R262_All_Sx, NF_R262_All_Sy = [], []

for angle in offaxisAngles:
    # Loading Rays:
    Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_'+'{:.1f}'.format(angle)+'.csv')
    # Fix little bug in rays:
    for ray in Brays:
        ray.hist = ray.hist.tolist()
    # Create detector :
    detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper], # This is corrected by the detectors-paper distance
                    reso = [1024,1024])
    # Detector Catch rays:
    detector.catchRays(Brays)
    
    '''Defining D, H, and P rays for each blocker size: '''
    Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 )]
    Srays = [ray for ray in Brays if (ray.des[2]==paper and ray.tag[-4:] == 'ce-D' )]
    Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' )]
    Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' )]
    
    NF_R262_All_Drays.append(Drays)
    NF_R262_All_Srays.append(Srays)
    NF_R262_All_Hrays.append(Hrays)
    NF_R262_All_Prays.append(Prays)    

    sim_scale = 1.0    # 1cm = 17.4 arcmin    
    
    
    #Hyperboloid
    Hx, Hy = [], []
    for ray in Hrays:
        Hx.append(ray.pos[0]*sim_scale)
        Hy.append(ray.pos[1]*sim_scale)
    NF_R262_All_Hx.append(Hx)
    NF_R262_All_Hy.append(Hy)
        
    # Paraboloid
    Px, Py = [], []
    for ray in Prays:
        Px.append(ray.pos[0]*sim_scale)
        Py.append(ray.pos[1]*sim_scale)
    NF_R262_All_Px.append(Px)
    NF_R262_All_Py.append(Py)
    
    # StraightThrough
    Sx, Sy = [], []
    for ray in Srays:
        Sx.append(ray.pos[0]*sim_scale)
        Sy.append(ray.pos[1]*sim_scale)
    NF_R262_All_Sx.append(Sx)
    NF_R262_All_Sy.append(Sy)    
    
        
    # Double
    Dx, Dy = [], []
    for ray in Drays:
        Dx.append(ray.pos[0]*sim_scale)
        Dy.append(ray.pos[1]*sim_scale)
    NF_R262_All_Dx.append(Dx)
    NF_R262_All_Dy.append(Dy)
# Out:
# /Users/Kamilobu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.0.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.2.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.4.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.6.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.8.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.0.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.2.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.4.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.6.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.8.csv loaded.

# %%
fig = plt.figure(figsize=(15,35))
st = fig.suptitle("Front Blocker = 3.75 & Rear Blocker = 3.135cm", fontsize=30,y=0.92)
for i, angle in enumerate(offaxisAngles):
    plt.subplot(7,3,i+1)
    plt.title('FOXSI 15m - Off-Axis Angle = '+'{:.1f}'.format(angle)+'arcmin',fontsize=14)
    plt.ylabel('cm',fontsize=14)
    plt.yticks(fontsize=12)
    plt.xticks(fontsize=12)
    plt.scatter(NF_R262_All_Hx[i],NF_R262_All_Hy[i],color='red',s=.01,alpha=0.8)
    plt.scatter(NF_R262_All_Px[i],NF_R262_All_Py[i],color='blue',s=.01,alpha=0.8)
    plt.scatter(NF_R262_All_Dx[i],NF_R262_All_Dy[i],color='green',s=.01,alpha=0.8)
    plt.scatter(NF_R262_All_Sx[i],NF_R262_All_Sy[i],color='black',s=.01,alpha=0.8)
    plt.ylim(-5.0,5.0)
    plt.xlim(-5.0,5.0)
    plt.tick_params(labelsize=8)
    ax = plt.gca()
    ax.add_patch(patches.Rectangle((-0.48,-0.48),0.96,0.96,fill=False,linewidth=0.5))
    #ax.add_patch(patches.Circle((0,0),np.sqrt(0.48),fill=False,linewidth=0.5,alpha=0.5))
plt.show()

# %% [markdown]
# # Method for finding off-axis angle

# %% [markdown]
# ## 0.0 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.0.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.0.csv loaded.

# %%
A00V0 = -1.87
A00V1 = -1.25
A00V2 = -0.7
A00V3 = -0.5
A00V4 = 0.5
A00V5 = 0.7
A00V6 = 1.26
A00V7 = 1.87

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("0.0 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A00V0,c='gray')
plt.axvline(A00V1,c='gray')
plt.axvline(A00V2,c='gray')
plt.axvline(A00V3,c='gray')
plt.axvline(A00V4,c='gray')
plt.axvline(A00V5,c='gray')
plt.axvline(A00V6,c='gray')
plt.axvline(A00V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.004875710390421461

# %% [markdown]
# ## 0.2 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.2.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.2.csv loaded.

# %%
A02V0 = -1.85
A02V1 = -1.23
A02V2 = -0.72
A02V3 = -0.5
A02V4 = 0.49
A02V5 = 0.7
A02V6 = 1.27
A02V7 = 1.88

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("0.2 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A02V0,c='gray')
plt.axvline(A02V1,c='gray')
plt.axvline(A02V2,c='gray')
plt.axvline(A02V3,c='gray')
plt.axvline(A02V4,c='gray')
plt.axvline(A02V5,c='gray')
plt.axvline(A02V6,c='gray')
plt.axvline(A02V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.011713340852105129

# %% [markdown]
# ## 0.4 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.4.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.4.csv loaded.

# %%
A04V0 = -1.85
A04V1 = -1.24
A04V2 = -0.73
A04V3 = -0.51
A04V4 = 0.47
A04V5 = 0.68
A04V6 = 1.28
A04V7 = 1.89

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("0.4 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A04V0,c='gray')
plt.axvline(A04V1,c='gray')
plt.axvline(A04V2,c='gray')
plt.axvline(A04V3,c='gray')
plt.axvline(A04V4,c='gray')
plt.axvline(A04V5,c='gray')
plt.axvline(A04V6,c='gray')
plt.axvline(A04V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  0.02816825981654381

# %% [markdown]
# # 0.6 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.6.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.6.csv loaded.

# %%
A06V0 = -1.83
A06V1 = -1.22
A06V2 = -0.73
A06V3 = -0.53
A06V4 = 0.47
A06V5 = 0.68
A06V6 = 1.3
A06V7 = 1.9

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("0.6 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A06V0,c='gray')
plt.axvline(A06V1,c='gray')
plt.axvline(A06V2,c='gray')
plt.axvline(A06V3,c='gray')
plt.axvline(A06V4,c='gray')
plt.axvline(A06V5,c='gray')
plt.axvline(A06V6,c='gray')
plt.axvline(A06V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.0005803902126791384

# %% [markdown]
# ## 0.8 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.8.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_0.8.csv loaded.

# %%
A08V0 = -1.83
A08V1 = -1.2
A08V2 = -0.75
A08V3 = -0.53
A08V4 = 0.46
A08V5 = 0.66
A08V6 = 1.3
A08V7 = 1.9


fig = plt.figure(figsize=(10,4))
st = fig.suptitle("0.8 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A08V0,c='gray')
plt.axvline(A08V1,c='gray')
plt.axvline(A08V2,c='gray')
plt.axvline(A08V3,c='gray')
plt.axvline(A08V4,c='gray')
plt.axvline(A08V5,c='gray')
plt.axvline(A08V6,c='gray')
plt.axvline(A08V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.050197831629845265

# %% [markdown]
# ## 1.0 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.0.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.0.csv loaded.

# %%
A10V0 = -1.81
A10V1 = -1.18
A10V2 = -0.76
A10V3 = -0.54
A10V4 = 0.44
A10V5 = 0.66
A10V6 = 1.32
A10V7 = 1.92

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("1.0 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A10V0,c='gray')
plt.axvline(A10V1,c='gray')
plt.axvline(A10V2,c='gray')
plt.axvline(A10V3,c='gray')
plt.axvline(A10V4,c='gray')
plt.axvline(A10V5,c='gray')
plt.axvline(A10V6,c='gray')
plt.axvline(A10V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.03038829335077152

# %% [markdown]
# ## 1.2 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.2.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.2.csv loaded.

# %%
A12V0 = -1.81
A12V1 = -1.17
A12V2 = -0.76
A12V3 = -0.56
A12V4 = 0.44
A12V5 = 0.64
A12V6 = 1.33
A12V7 = 1.93

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("1.2 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A12V0,c='gray')
plt.axvline(A12V1,c='gray')
plt.axvline(A12V2,c='gray')
plt.axvline(A12V3,c='gray')
plt.axvline(A12V4,c='gray')
plt.axvline(A12V5,c='gray')
plt.axvline(A12V6,c='gray')
plt.axvline(A12V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.03637490089643657

# %% [markdown]
# # 1.4 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.4.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.4.csv loaded.

# %%
A14V0 = -1.79
A14V1 = -1.16
A14V2 = -0.78
A14V3 = -0.56
A14V4 = 0.42
A14V5 = 0.63
A14V6 = 1.34
A14V7 = 1.94

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("1.4 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A14V0,c='gray')
plt.axvline(A14V1,c='gray')
plt.axvline(A14V2,c='gray')
plt.axvline(A14V3,c='gray')
plt.axvline(A14V4,c='gray')
plt.axvline(A14V5,c='gray')
plt.axvline(A14V6,c='gray')
plt.axvline(A14V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.045241524265826644

# %% [markdown]
# ## 1.6 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.6.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.6.csv loaded.

# %%
A16V0 = -1.78
A16V1 = -1.15
A16V2 = -0.79
A16V3 = -0.57
A16V4 = 0.41
A16V5 = 0.62
A16V6 = 1.35
A16V7 = 1.95

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("1.6 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A16V0,c='gray')
plt.axvline(A16V1,c='gray')
plt.axvline(A16V2,c='gray')
plt.axvline(A16V3,c='gray')
plt.axvline(A16V4,c='gray')
plt.axvline(A16V5,c='gray')
plt.axvline(A16V6,c='gray')
plt.axvline(A16V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  -0.00039698452838436764

# %% [markdown]
# ## 1.8 arcmin

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.8.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=40,
                    height=40,
                    normal = [0,0,1],
                    center = [0,0,paper],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

# Selecting rays on focal plane
yth=0.1
Drays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==2 and ray.des[1]>=-yth and ray.des[1]<=yth)]
Hrays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]
Prays = [ray for ray in Brays if (ray.des[2]==paper and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' ) and ray.des[1]>=-yth and ray.des[1]<=yth]

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)
        
# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/Laser_Alignment/WSMR/X4/rays/rays_Angle_=_1.8.csv loaded.

# %%
A18V0 = -1.78
A18V1 = -1.14
A18V2 = -0.80
A18V3 = -0.59
A18V4 = 0.4
A18V5 = 0.61
A18V6 = 1.36
A18V7 = 1.96

fig = plt.figure(figsize=(10,4))
st = fig.suptitle("1.8 arcmin off-axis Sim [X4]", fontsize=16,y=0.95)
plt.subplot(2,1,1)
plt.scatter(Dx,Dy,color='green',s=.1,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=.1,alpha=0.8)
plt.scatter(Hx,Hy,color='red',s=.1,alpha=0.8)
# Histogram 
plt.subplot(2,1,2)
plt.hist(Dx,bins=100,color='g')
plt.hist(Px,bins=100,color='b')
plt.hist(Hx,bins=100,color='r')
plt.axvline(A18V0,c='gray')
plt.axvline(A18V1,c='gray')
plt.axvline(A18V2,c='gray')
plt.axvline(A18V3,c='gray')
plt.axvline(A18V4,c='gray')
plt.axvline(A18V5,c='gray')
plt.axvline(A18V6,c='gray')
plt.axvline(A18V7,c='gray')
plt.show()
print('Mean = ',np.mean(Dx + Px))
# Out:
# Mean =  0.031244923661344043

# %%
V0 = np.array([A00V0,A02V0,A04V0,A06V0,A08V0,A10V0,A12V0,A14V0,A16V0,A18V0])
V1 = np.array([A00V1,A02V1,A04V1,A06V1,A08V1,A10V1,A12V1,A14V1,A16V1,A18V1])
V2 = np.array([A00V2,A02V2,A04V2,A06V2,A08V2,A10V2,A12V2,A14V2,A16V2,A18V2])
V3 = np.array([A00V3,A02V3,A04V3,A06V3,A08V3,A10V3,A12V3,A14V3,A16V3,A18V3])
V4 = np.array([A00V4,A02V4,A04V4,A06V4,A08V4,A10V4,A12V4,A14V4,A16V4,A18V4])
V5 = np.array([A00V5,A02V5,A04V5,A06V5,A08V5,A10V5,A12V5,A14V5,A16V5,A18V5])
V6 = np.array([A00V6,A02V6,A04V6,A06V6,A08V6,A10V6,A12V6,A14V6,A16V6,A18V6])
V7 = np.array([A00V7,A02V7,A04V7,A06V7,A08V7,A10V7,A12V7,A14V7,A16V7,A18V7])

# %%
param = ((V7+V6)-(V5+V4))/((V3+V2)-(V1+V0))
param1 = (V6-V5)/(V2-V1)
param2 = (V7-V5)/(V2-V0)

# %%
## Consistency:
X4param0712C = 1.1378

## Loss Bolts:
X4param0712LB = 1.079

## Laser Aligned:
X4param0712LA = 1.109

# Linear regression
p = np.poly1d(np.polyfit(param, offaxisAngles, 1))

## Consistency:
print('X4 Miss align angle Consistency = %f arcmin' % p(X4param0712C))

print('\n'+'*'*50+'\n')

## Loss Bolts:
print('X4 Miss align angle Loss Bolts = %f arcmin' % p(X4param0712LB))
print('\n'+'*'*50+'\n')

## Laser Aligned:
print('X4 Miss align angle Laser Aligned = %f arcmin' % p(X4param0712LA))
# Out:
# X4 Miss align angle Consistency = 0.539166 arcmin
#
# **************************************************
#
# X4 Miss align angle Loss Bolts = 0.332568 arcmin
#
# **************************************************
#
# X4 Miss align angle Laser Aligned = 0.437975 arcmin

# %%
plt.figure(figsize=(8,6))
plt.plot(offaxisAngles,param,'o-')
plt.xlabel('off-axis angle [arcmin]')
plt.ylabel('Asymmetry parameter')
plt.title('X4 - 7-Shell + 3DPC',fontsize='28')
plt.plot(p(param),param)
## Consistency:
plt.axhline(X4param0712C,color='r',linestyle='dashed',alpha=0.7,label='0712 - Consistency')
plt.axvline(p(X4param0712C),color='r',linestyle='dashed',alpha=0.7)
## Loss Bolts:
plt.axhline(X4param0712LB,color='r',linestyle='-',alpha=0.7,label='0712 - Loss Bolts')
plt.axvline(p(X4param0712LB),color='r',linestyle='-',alpha=0.7)
## Laser ALigned:
plt.axhline(X4param0712LA,color='r',linestyle='-.',alpha=0.7,label='0712 - Laser Aligned')
plt.axvline(p(X4param0712LA),color='r',linestyle='-.',alpha=0.7)
plt.legend()
