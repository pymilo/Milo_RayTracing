# %% [markdown]
# # Debugging Rear Blocker

# %% [markdown]
# ## Feb, 2018
# ## @Milo

# %% [markdown]
# ***All simulation in this notebook have been run using the my Fork located at https://github.com/pymilo/foxsi-optics-sim/tree/Random-Source-Debugg Branch: Random-Source-Debugg ***

# %% [markdown]
# Last thing I did before today was including a version of the Rear Blocker in the `module.py` file of the simulation: Lines ~ 195 and below.

# %% [markdown]
# To create the rays I'm using the script located at `/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_Rblockers.py` and I'm saving the rays in the folder: `rays_RB/test/`

# %% [markdown]
# ### Create rays for testing here:

# %%
import numpy as np
from foxsisim.source import Source
from foxsisim.module import Module
from foxsisim.util import load_rays, save_rays
from foxsisim.detector import Detector

n = 10                 ## number of rays
Sdist = -1.5e13        ## cm
offaxisAngle = 0.0     ## arcmin
fbr = 3.17
rbr = 0.0 

#rbrs = np.arange(0.0,2.855,0.2) # Rear blocker radius ranging from 0.0cm to 2.8 in steps of 0.2
#Create Source : 
source = Source(type='point',center=[0, -Sdist * np.sin(np.deg2rad(offaxisAngle / 60.0)), Sdist ])

print('Rear radius: %f' % rbr)
module = Module(radii = [3.17], core_radius=(fbr,rbr))
rays = source.generateRays(module.targetFront,n)
module.passRays(rays)
Rrays = [ray for ray in rays if (ray.tag != 'Source')] #kills the passthrough rays
save_rays(Rrays,filename='/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_00.csv')
# Out:
# Rear radius: 0.000000
# Rays saved in file : /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_00.csv

# %%
from foxsisim.util import load_rays
from foxsisim.detector import Detector
import matplotlib.pyplot as plt

# %%
# Loading Rays:
Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_00.csv')
# Fix little bug in rays:
for ray in Brays:
    ray.hist = ray.hist.tolist()
# Create detector :
detector = Detector(width=10,
                    height=10,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])
# Detector Catch rays:
detector.catchRays(Brays)

'''Defining D, H, and P rays for each blocker size: '''
Drays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==2 )]
Srays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==1 )]
Hrays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' )]
Prays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' )]
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_00.csv loaded.

# %%
Drays
# Out:
# [<foxsisim.ray.Ray at 0x11637b978>,
#  <foxsisim.ray.Ray at 0x1a1fc8e0f0>,
#  <foxsisim.ray.Ray at 0x112a98828>,
#  <foxsisim.ray.Ray at 0x1a1fc8e0b8>,
#  <foxsisim.ray.Ray at 0x11637b9e8>,
#  <foxsisim.ray.Ray at 0x1a1fc8e278>,
#  <foxsisim.ray.Ray at 0x1163e62e8>,
#  <foxsisim.ray.Ray at 0x1a1fc8e358>,
#  <foxsisim.ray.Ray at 0x1163e62b0>,
#  <foxsisim.ray.Ray at 0x1a1fc8e320>]

# %% [markdown]
# # Testing

# %%
from foxsisim.util import load_rays
from foxsisim.detector import Detector
import matplotlib.pyplot as plt 
import numpy as np

rbrs = np.arange(0.0,2.805,0.2) # Rear blocker radii

All_Drays, All_Hrays, All_Prays = [], [], []
All_Dx, All_Dy, All_Hx, All_Hy, All_Px, All_Py = [], [], [], [], [], []

for rbr in rbrs:
    # Loading Rays:
    Brays = load_rays('/Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_'+str(rbr)+'.csv')
    # Fix little bug in rays:
    for ray in Brays:
        ray.hist = ray.hist.tolist()
    # Create detector :
    detector = Detector(width=10,
                    height=10,
                    normal = [0,0,1],
                    center = [0,0,230],
                    reso = [1024,1024])
    # Detector Catch rays:
    detector.catchRays(Brays)
    
    '''Defining D, H, and P rays for each blocker size: '''
    Drays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==2 )]
    Srays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==1 )]
    Hrays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' )]
    Prays = [ray for ray in Brays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' )]

    All_Drays.append(Drays)
    All_Hrays.append(Hrays)
    All_Prays.append(Prays)
    
    sim_scale = 1.0    # 1cm = 17.4 arcmin
    #sim_scale = 17.4    # 1cm = 17.4 arcmin

    #Hyperboloid
    Hx, Hy = [], []
    for ray in Hrays:
        Hx.append(ray.pos[0]*sim_scale)
        Hy.append(ray.pos[1]*sim_scale)
    All_Hx.append(Hx)
    All_Hy.append(Hy)
        
    # Paraboloid
    Px, Py = [], []
    for ray in Prays:
        Px.append(ray.pos[0]*sim_scale)
        Py.append(ray.pos[1]*sim_scale)
    All_Px.append(Px)
    All_Py.append(Py)
        
    # Double
    Dx, Dy = [], []
    for ray in Drays:
        Dx.append(ray.pos[0]*sim_scale)
        Dy.append(ray.pos[1]*sim_scale)
    All_Dx.append(Dx)
    All_Dy.append(Dy)
# Out:
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_0.0.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_0.2.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_0.4.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_0.6.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_0.8.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_1.0.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_1.2.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_1.4.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_1.6.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_1.8.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_2.0.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_2.2.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_2.4.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_2.6.csv loaded.
# Rays from /Users/Kamilobu/Desktop/Developer/Milo_RayTracing/blockers/rays_RB/test/rays_RBR_=_2.8.csv loaded.

# %%
fig = plt.figure(figsize=(15,25))
for i, rbr in enumerate(rbrs):
    plt.subplot(5,3,i+1)
    plt.title('FOXSI 1AU - FBR = '+str(rbr)+'cm',fontsize=14)
    plt.ylabel('cm',fontsize=18)
    plt.yticks(fontsize=12)
    plt.xticks(fontsize=12)
    plt.scatter(All_Hx[i],All_Hy[i],color='red',s=10.,alpha=0.8)
    plt.scatter(All_Px[i],All_Py[i],color='blue',s=10.,alpha=0.8)
    plt.scatter(All_Dx[i],All_Dy[i],color='green',s=10.,alpha=0.8)
    plt.ylim(-2.5,2.5)
    plt.xlim(-2.5,2.5)
plt.show()

# %%
Rout = 3.29
fbr = 3.17
Doubles, Hyp, Par = [], [], []
for i, rbr in enumerate(rbrs):
    Doubles.append(len(All_Drays[i]) * (Rout**2 - fbr**2))
    Hyp.append(len(All_Hrays[i]) * (Rout**2 - fbr**2))
    Par.append(len(All_Prays[i]) * (Rout**2 - fbr**2))

# %%
plt.plot(Doubles/max(np.array(Doubles)))

# %%
# Plotting :
fig = plt.figure(figsize=(10,8))
plt.title('Vignetting vs. Rear blocker - Front blocker = 3.17cm',fontsize=18)
plt.semilogy(rbrs, Doubles/max(np.array(Doubles)),'go-',label='Dobles')
plt.semilogy(rbrs, Hyp/max(np.array(Doubles)),'ro-',label='Hyperboloids')
plt.semilogy(rbrs, Par/max(np.array(Doubles)),'bo-',label='Paraboloid')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Relative intensity respect normalized Doubles',fontsize=18)
plt.xlabel('Rear blocker radius [cm]',fontsize=18)
#plt.axvline(3.17,color='purple',linestyle='--',lw=0.8)
#plt.text(3.155,5e-1,'Most efficient front blocker size = 3.17cm',rotation=90,fontsize=12,color='purple')
plt.legend(fontsize=14)
plt.show()

# %%
# Plotting :
fig = plt.figure(figsize=(10,8))
plt.title('Vignetting vs. Rear blocker - Front blocker = 3.17cm',fontsize=18)
plt.plot(rbrs, Doubles/max(np.array(Doubles)),'go-',label='Dobles')
#plt.semilogy(rbrs, Hyp/max(Doubles),'ro-',label='Hyperboloids')
plt.plot(rbrs, Par/max(np.array(Doubles)),'bo-',label='Paraboloid')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Relative intensity respect normalized Doubles',fontsize=18)
plt.xlabel('Rear blocker radius [cm]',fontsize=18)
#plt.axvline(3.17,color='purple',linestyle='--',lw=0.8)
#plt.text(3.155,5e-1,'Most efficient front blocker size = 3.17cm',rotation=90,fontsize=12,color='purple')
plt.legend(fontsize=14)
plt.show()
