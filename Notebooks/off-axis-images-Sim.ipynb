# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from astropy.io import fits
from foxsisim.detector import Detector
from foxsisim.plotting import plot, scatterHist
from foxsisim.util import load_rays
import numpy as np
import ast
import matplotlib.colors

# %%
# 16 arcmin
fits16 = fits.open('/Users/Kamilobu/Desktop/FOXSI/FOXSI-3/FOXSI-SIM-ANALYSIS/FOXSI3Data/Foxsi_mod6_16arcmin_0.5mA.fits')
data16 = fits16[0]

# 18 arcmin
fits18 = fits.open('/Users/Kamilobu/Desktop/FOXSI/FOXSI-3/FOXSI-SIM-ANALYSIS/FOXSI3Data/Foxsi_mod6_18arcmin_0.5mA.fits')
data18 = fits18[0]


# 20 arcmin
fits20 = fits.open('/Users/Kamilobu/Desktop/FOXSI/FOXSI-3/FOXSI-SIM-ANALYSIS/FOXSI3Data/Foxsi_mod6_20arcmin_0.5mA.fits')
data20 = fits20[0]


# 22 arcmin
fits22 = fits.open('/Users/Kamilobu/Desktop/FOXSI/FOXSI-3/FOXSI-SIM-ANALYSIS/FOXSI3Data/Foxsi_mod6_22arcmin_0.5mA.fits')
data22 = fits22[0]


# 24 arcmin
fits24 = fits.open('/Users/Kamilobu/Desktop/FOXSI/FOXSI-3/FOXSI-SIM-ANALYSIS/FOXSI3Data/Foxsi_mod6_24arcmin_0.5mA.fits')
data24 = fits24[0]

# 26 arcmin
fits26 = fits.open('/Users/Kamilobu/Desktop/FOXSI/FOXSI-3/FOXSI-SIM-ANALYSIS/FOXSI3Data/Foxsi_mod6_26arcmin_0.5mA.fits')
data26 = fits26[0]


fig = plt.figure(figsize=(20,14))
plt.subplot(231)
plt.title('Source 16 arcmin off-axis',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(data16.data[0,:,:], origin='lower',cmap='Greys',
           norm=matplotlib.colors.LogNorm(),vmin=1250,vmax=2500, extent=[0,22.187,0,22.187])
plt.subplot(232)
plt.title('Source 18 arcmin off-axis',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(data18.data[0,:,:], origin='lower',cmap='Greys',
           norm=matplotlib.colors.LogNorm(),vmin=1250,vmax=2500, extent=[0,22.187,0,22.187])
plt.subplot(233)
plt.title('Source 20 arcmin off-axis',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(data20.data[0,:,:], origin='lower',cmap='Greys',
           norm=matplotlib.colors.LogNorm(),vmin=1250,vmax=2500, extent=[0,22.187,0,22.187])
plt.subplot(234)
plt.title('Source 22 arcmin off-axis',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(data22.data[0,:,:], origin='lower',cmap='Greys',
           norm=matplotlib.colors.LogNorm(),vmin=1250,vmax=2500, extent=[0,22.187,0,22.187])
plt.subplot(235)
plt.title('Source 24 arcmin off-axis',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(data24.data[0,:,:], origin='lower',cmap='Greys',
           norm=matplotlib.colors.LogNorm(),vmin=1250,vmax=2500, extent=[0,22.187,0,22.187])
plt.subplot(236)
plt.title('Source 26 arcmin off-axis',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(data26.data[0,:,:], origin='lower',cmap='Greys',
           norm=matplotlib.colors.LogNorm(),vmin=1250,vmax=2500, extent=[0,22.187,0,22.187])

plt.savefig('off-axis.png',pad_inches=0.0)

# %%
plt.savefig?

# %%
1024*1.3/60
# Out:
# 22.186666666666667
