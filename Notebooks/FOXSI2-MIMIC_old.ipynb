# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
import ast
import matplotlib.colors

# %% [markdown]
# # SIMULATION AR1

# %%
## Reading Rays
import matplotlib.pyplot as plt
from foxsisim.util import load_rays
from foxsisim.plotting import plot,scatterHist
Rrays = load_rays('/Users/Kamilobu/Desktop/FOXSI2_Sim/AR1/100m/run00.csv')
print('Number of rays : {:d}'.format(len(Rrays)))
Drays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==2 )]
Srays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==1 )]
Hrays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' )]
Prays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' )]

sim_scale = 17.4    # 1cm = 17.4 arcmin

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)

# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/FOXSI2_Sim/AR1/100m/run00.csv loaded.
# Number of rays : 100000

# %% [markdown]
# ## Hyperboloids on top

# %%
fig = plt.figure(figsize=(20,20))
plt.title('FOXSI2 Quiet-Sun Sim Mimic - 100m',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.axvline(x=0.0,color='gray')
plt.axhline(y=0.0,color='gray')
plt.scatter(Hx,Hy,color='red',s=10.0,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=10.0,alpha=0.8)
plt.scatter(Dx,Dy,color='green',s=10.0,alpha=0.8)
plt.ylim(-50,10)
plt.xlim(-50,10)
# Out:
# (-50, 10)

# %% [markdown]
# # 1AU

# %% [markdown]
# ## AR1

# %%
## Reading Rays
Rrays = load_rays('/Users/Kamilobu/Desktop/FOXSI2_Sim/AR1/150Gm/run00.csv')
print('Number of rays : {:d}'.format(len(Rrays)))
Drays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==2 )]
Srays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==1 )]
Hrays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' )]
Prays = [ray for ray in Rrays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' )]

sim_scale = 17.4    # 1cm = 17.4 arcmin

#Hyperboloid
Hx, Hy = [], []
for ray in Hrays:
    Hx.append(ray.pos[0]*sim_scale)
    Hy.append(ray.pos[1]*sim_scale)

# Paraboloid
Px, Py = [], []
for ray in Prays:
    Px.append(ray.pos[0]*sim_scale)
    Py.append(ray.pos[1]*sim_scale)

# Double
Dx, Dy = [], []
for ray in Drays:
    Dx.append(ray.pos[0]*sim_scale)
    Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/FOXSI2_Sim/AR1/150Gm/run00.csv loaded.
# Number of rays : 100000

# %% [markdown]
# ## AR2

# %%
AR2Rrays = load_rays('/Users/Kamilobu/Desktop/FOXSI2_Sim/AR2/100m/run00.csv')
print('Number of rays : {:d}'.format(len(Rrays)))
AR2Drays = [ray for ray in AR2Rrays if (ray.des[2]==230.0 and ray.bounces ==2 )]
AR2Srays = [ray for ray in AR2Rrays if (ray.des[2]==230.0 and ray.bounces ==1 )]
AR2Hrays = [ray for ray in AR2Rrays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Hy-D' )]
AR2Prays = [ray for ray in AR2Rrays if (ray.des[2]==230.0 and ray.bounces ==1 and ray.tag[-4:] == 'Pa-D' )]

sim_scale = 17.4    # 1cm = 17.4 arcmin

#Hyperboloid
AR2Hx, AR2Hy = [], []
for ray in AR2Hrays:
    AR2Hx.append(ray.pos[0]*sim_scale)
    AR2Hy.append(ray.pos[1]*sim_scale)

# Paraboloid
AR2Px, AR2Py = [], []
for ray in AR2Prays:
    AR2Px.append(ray.pos[0]*sim_scale)
    AR2Py.append(ray.pos[1]*sim_scale)

# Double
AR2Dx, AR2Dy = [], []
for ray in AR2Drays:
    AR2Dx.append(ray.pos[0]*sim_scale)
    AR2Dy.append(ray.pos[1]*sim_scale)
# Out:
# Rays from /Users/Kamilobu/Desktop/FOXSI2_Sim/AR2/100m/run00.csv loaded.
# Number of rays : 100000

# %% [markdown]
# ## plotting

# %%
fig = plt.figure(figsize=(20,20))
plt.title('AR1 FOXSI2 Quiet-Sun Sim Mimic - 1AU',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.axvline(x=0.0,color='gray')
plt.axhline(y=0.0,color='gray')
plt.scatter(Hx,Hy,color='red',s=10.0,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=10.0,alpha=0.8)
plt.scatter(Dx,Dy,color='green',s=10.0,alpha=0.8)
plt.ylim(-50,10)
plt.xlim(-50,10)
# Out:
# (-50, 10)

# %%
fig = plt.figure(figsize=(20,20))
plt.title('AR2 FOXSI2 Quiet-Sun Sim Mimic - 1AU',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.axvline(x=0.0,color='gray')
plt.axhline(y=0.0,color='gray')
plt.scatter(AR2Hx,AR2Hy,color='red',s=10.0,alpha=0.8)
plt.scatter(AR2Px,AR2Py,color='blue',s=10.0,alpha=0.8)
plt.scatter(AR2Dx,AR2Dy,color='green',s=10.0,alpha=0.8)
plt.ylim(-50,10)
plt.xlim(-50,10)
# Out:
# (-50, 10)

# %% [markdown]
# ## Target 4 FOXSI 2 - Data

# %%
XC, YC = 200./60, 750/60
X0, Y0, XF, YF = -403.3/60, 152.3/60, 797.8/60, 1353.4/60
T4, header = fits.getdata('/Users/Kamilobu/Desktop/T4_Fits/foxsi_T4_d6.fits', header=True)

# %%
fig = plt.figure(figsize=(20,20))
plt.title('FOXSI2 Quiet-Sun Sim Mimic - 1AU',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.axvline(x=0.0,color='gray')
plt.axhline(y=0.0,color='gray')
#plt.scatter(Hx,Hy,color='red',s=10.0,alpha=0.8)
#plt.scatter(Px,Py,color='blue',s=10.0,alpha=0.8)
#plt.scatter(Dx,Dy,color='green',s=10.0,alpha=0.8)
cmap = plt.cm.binary
cmap.set_under(color='white')
plt.imshow(T4,origin='lower',extent=[X0-XC,XF-XC,Y0-YC,YF-YC],cmap=cmap,vmin=0.0005)
plt.ylim(-50,10)
plt.xlim(-50,10)
# Out:
# (-50, 10)

# %%
fig = plt.figure(figsize=(20,20))
plt.title('AR1 FOXSI2 Quiet-Sun Sim Mimic - 1AU',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.axvline(x=0.0,color='gray')
plt.axhline(y=0.0,color='gray')
plt.scatter(Hx,Hy,color='red',s=10.0,alpha=0.8)
plt.scatter(Px,Py,color='blue',s=10.0,alpha=0.8)
plt.scatter(Dx,Dy,color='green',s=10.0,alpha=0.8)
cmap = plt.cm.binary
cmap.set_under(color='white')
plt.imshow(T4,origin='lower',extent=[X0-XC,XF-XC,Y0-YC,YF-YC],cmap=cmap,vmin=0.0005)
plt.ylim(-50,10)
plt.xlim(-50,10)
# Out:
# (-50, 10)

# %%
fig = plt.figure(figsize=(20,20))
plt.title('AR2 FOXSI2 Quiet-Sun Sim Mimic - 1AU',fontsize=24)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.axvline(x=0.0,color='gray')
plt.axhline(y=0.0,color='gray')
plt.scatter(AR2Hx,AR2Hy,color='red',s=10.0,alpha=0.8)
plt.scatter(AR2Px,AR2Py,color='blue',s=10.0,alpha=0.8)
plt.scatter(AR2Dx,AR2Dy,color='green',s=10.0,alpha=0.8)
cmap = plt.cm.binary
cmap.set_under(color='white')
plt.imshow(T4,origin='lower',extent=[X0-XC,XF-XC,Y0-YC,YF-YC],cmap=cmap,vmin=0.0005)
plt.ylim(-50,10)
plt.xlim(-50,10)
# Out:
# (-50, 10)
